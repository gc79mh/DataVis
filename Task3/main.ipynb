# %% [raw]
# title: Project 3
# author: Antonina Gardzielewska and Wiktor Bochenski
# output:
#     general:
#         input: false
#     html:
#         toc: true
#         toc_depth: 2

# %%
# %load_ext pretty_jupyter

# %%
import numpy as np
import pandas as pd
import plotly
import plotly.offline as pyo
import plotly.express as px
pyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %% [markdown]
# # Datasets
#
# Firstly we read in and try to understand the data

# %%
services = pd.read_csv("services_annual_dataset.csv", encoding="1250", low_memory=False)
merchandise = pd.read_csv("merchandise_values_annual_dataset.csv", encoding="1250", low_memory=False)

# %% [markdown]
# ## Overview

# %% [markdown]
# Datasets are lists of transactions between parties of given services / merchandise

# %% [markdown]
# ## Preprocess

# %% [markdown]
# First of all we've dropped most of the collumns instead of a couple that we though would be the most interesting for the analysis.
#
# Second thing we did was simplify the indicator collumn so it would contain only the import or export word.
#
# And lastly from both data frames we deleted the "Total" and "0" rows as well as rows which had "World" as a Reporter

# %%
merchandise.drop(columns = ["IndicatorCategory", "IndicatorCode", "ReporterCode", "PartnerCode", "ProductClassificationCode", "ProductCode", "PeriodCode", "Period", "FrequencyCode", "Frequency", "UnitCode", "ValueFlagCode", "ValueFlag", "Unit", "ProductClassification"], inplace=True)

services.drop(columns = [ "ProductClassification", "IndicatorCategory", "IndicatorCode", "ReporterCode", "PartnerCode", "ProductClassificationCode", "ProductCode", "PeriodCode", "Period", "FrequencyCode", "Frequency", "UnitCode", "ValueFlagCode", "ValueFlag", "Unit"], inplace=True)

# %%
services.loc[services["Indicator"] == 'Commercial services imports by sector - annual (1980-2013)', "Indicator"] = "Import"
services.loc[services["Indicator"] == 'Commercial services imports by sector and partner - annual', "Indicator"] = "Import"
services.loc[services["Indicator"] == 'Commercial services exports by sector - annual  (1980-2013)', "Indicator"] = "Export"
services.loc[services["Indicator"] == 'Commercial services exports by sector and partner - annual', "Indicator"] = "Export"

merchandise.loc[merchandise["Indicator"] == 'Merchandise exports by product group - annual', "Indicator"] = "Export"
merchandise.loc[merchandise["Indicator"] == 'Merchandise imports by product group - annual', "Indicator"] = "Import"

# %%
services = services[services["Product"] != "Memo item: Total services"]
services = services[services["Reporter"] != "World"]

merchandise = merchandise[merchandise["Product"] != "Total merchandise"]
merchandise = merchandise[merchandise["Reporter"] != "World"]

# %%
services = services[services["Value"] != 0]

merchandise = merchandise[merchandise["Value"] != 0]

# %% [markdown]
# ## Final data frame
# [//]: # (-.- .tabset .tabset-pills)

# %% [markdown]
# Here are the first 5 rows of the data frames we will be working on

# %% [markdown]
# ### Services

# %%
services.sample(n=5).reset_index(drop=True)
# Out:
#   Indicator ReporterISO3A                                     Reporter  \
# 0    Import           DEU                                      Germany
# 1    Export           NaN                        Non-EU western Europe
# 2    Export           NaN  African, Caribbean and Pacific States (ACP)
# 3    Import           SWE                                       Sweden
# 4    Import           FRA                                       France
#
#   PartnerISO3A         Partner  \
# 0          NaN           World
# 1          NaN           World
# 2          NaN           World
# 3          AUT         Austria
# 4          NaN  Euro Area (20)
#
#                                              Product  Year  Value
# 0                         Royalties and license fees  1989   3027
# 1                                      Sea transport  2020  24412
# 2  Commercial services (Services excl. government...  1982   9968
# 3                                      Freight (Air)  2021      2
# 4                                     Legal services  2021    477

# %% [markdown]
# ### Merchandise

# %%
merchandise.sample(n=5).reset_index(drop=True)
# Out:
#   Indicator ReporterISO3A             Reporter PartnerISO3A Partner  \
# 0    Export           EST              Estonia          NaN   World
# 1    Export           TTO  Trinidad and Tobago          NaN   World
# 2    Import           BGR             Bulgaria          NaN   World
# 3    Import           MAC         Macao, China          NaN   World
# 4    Export           GEO              Georgia          NaN   World
#
#                              Product  Year  Value
# 0              Agricultural products  2000    514
# 1              Agricultural products  2023    503
# 2                Automotive products  2002    612
# 3                    Pharmaceuticals  2003     28
# 4  Machinery and transport equipment  1996     11

# %% [markdown]
# # Visualizations
# [//]: # (-.- .tabset .tabset-pills)

# %% [markdown]
# ## Total trade value

# %%
px.line(merchandise.groupby('Year')['Value'].sum().reset_index(), x='Year', y='Value', title='Total Trade Value Over Time (Merchandise)', template="plotly_white")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="14d40f05-8a53-452a-8417-92953a7466ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("14d40f05-8a53-452a-8417-92953a7466ac")) {                    Plotly.newPlot(                        "14d40f05-8a53-452a-8417-92953a7466ac",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"I7RiAPe4QwBQBj8Agm8\u002fAJm3QgBEvEMAmylLAPskWQADSWYAVKhuAE8r2QCDmdEA6YDkAFPW4QCVEgUBwvA9ARykTwFFkl8BfE1fARETcwEAfeoCtLzWAmNp\u002fwKg+4wDflVKBFG3xwTv4XAFHNlMBuIUFAeguW0FTwRrBj5AgweFOmMHgsaKB23orwfLDcwG0Iq2BvJDdQfeJDcIbaAACOZLcgejhDIJLTQ9CnQZ9Qk="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type ...

# %%
px.line(services.groupby('Year')['Value'].sum().reset_index(), x='Year', y='Value', title='Total Trade Value Over Time (Services)', template="plotly_white")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="f078c1c0-9a4c-4c86-9a2a-e90296f21e6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f078c1c0-9a4c-4c86-9a2a-e90296f21e6c")) {                    Plotly.newPlot(                        "f078c1c0-9a4c-4c86-9a2a-e90296f21e6c",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"k71rAEEYdQA4fHEA+oFxAOP1dQAu+nYAhcaHADxungA6RLQAMzzIABca6wAfBP0AWSsVAcyQRAHZjGQBFBWTAS1QuAEg08wBkmLNAVRE5QGfuiwCWG8wAuEFVgJEAKwC6\u002f+OAxzPORFslPcTY6OiF2jzWx1+zooZL6VEIB3YcSX1yGIm2bNnKH+uXyOLLWsg8BuyIIY4vCNKgE8nCm5mKNcIsiPgpvgqzvHSLxtLxys="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sc ...

# %% [markdown]
# ## Import vs Export vs Global Average

# %%
poland_services = services[services["Reporter"] == "Poland"]

mean_poland_services = (
    poland_services
    .groupby(["Year", "Indicator"], as_index=False)["Value"]
    .mean()
)
mean_poland_services["Reporter"] = "Poland"

mean_global_services = (
    services
    .groupby(["Year", "Indicator"], as_index=False)["Value"]
    .mean()
)
mean_global_services["Reporter"] = "Global Average"


df = pd.concat([mean_poland_services, mean_global_services], ignore_index=True)

fig = px.line(
    df,
    x="Year",
    y="Value",
    color="Reporter",
    line_dash="Indicator",
    markers=True,
    title=f"Poland: Mean Services Imports vs Exports vs Global Average",
    template='simple_white'
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3643ae1e-e48b-461e-bfec-6d0c2a293fd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3643ae1e-e48b-461e-bfec-6d0c2a293fd5")) {                    Plotly.newPlot(                        "3643ae1e-e48b-461e-bfec-6d0c2a293fd5",                        [{"hovertemplate":"Reporter=Poland\u003cbr\u003eIndicator=Export\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Poland, Export","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Poland, Export","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"\u002f1XXa1zaTQHTRRRdd1I5AJUmSJIlzc0ANVNBfupd1QAm2RzubbnVAg8gxtykMdEB5O\u002fbVR55yQJFeashKrXFAawJR33T9ckBcVI+uwkV2QK3BfRqdlHlA+v6M5o0DekD22zf22893QIPCTBXndX5AtXPLNsM4gECVcCeVcIahQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Poland\u003cbr\u003eIndicator=Import\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Poland, Import","line":{"color":"#1F77B4","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Poland, Import","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"...\u002fnFAdNFFF138cUBhCZhVC31vQDzNtHqEpHRA6ZkV6HVddkDMaC6jueWYQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Global Average\u003cbr\u003eIndicator=Export\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Global Average, Export","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Global Average, Export","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"\u002fmcRAsgGkuDBlx0CElAZuv77HQOabZu2ArsFAYXqnSllYsUAuC\u002fzGbuSyQJEdvaUBirJA\u002fR6YMJyAsUD7AVjjxAOuQNPkSJbu4K1A2BA3CPLrrEC\u002f76C\u002fxNuuQDjmxcz13rBAmXYAsrfDsEBZk3Mnr2SvQH5O8zpO0bJAY0tVl3BftEDgdV3ECknPQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Global Average\u003cbr\u003eIndicator=Import\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Global Average, Import","line":{"color":"#FF7F0E","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Global Average, Import","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"PuLxuio3pkBEuu3JiZmnQOIM5sJzuaVAMvC1QmUFpkDL8I0oMLKmQJdv+ZZvK6ZA+eNZvW6zp0CLFjQdj3irQAa\u002fPTWnXa9ACJx7C90\u002fsUAVgP8C7gi0QM4QpXNZL7VAD2gNuytAtkDd7WACWPa3QIiordloI ...

# %%
poland_merchandise = merchandise[merchandise["Reporter"] == "Poland"]

mean_poland_merchandise = (
    poland_merchandise
    .groupby(["Year", "Indicator"], as_index=False)["Value"]
    .mean()
)
mean_poland_merchandise["Reporter"] = "Poland"

mean_global_merchandise = (
    merchandise
    .groupby(["Year", "Indicator"], as_index=False)["Value"]
    .mean()
)
mean_global_merchandise["Reporter"] = "Global Average"


df = pd.concat([mean_poland_merchandise, mean_global_merchandise], ignore_index=True)

fig = px.line(
    df,
    x="Year",
    y="Value",
    color="Reporter",
    line_dash="Indicator",
    markers=True,
    title=f"Poland: Mean Merchandise Imports vs Exports vs Global Average",
    template='simple_white'
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c3b321e6-919d-4394-83de-bf8d48af14fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c3b321e6-919d-4394-83de-bf8d48af14fc")) {                    Plotly.newPlot(                        "c3b321e6-919d-4394-83de-bf8d48af14fc",                        [{"hovertemplate":"Reporter=Poland\u003cbr\u003eIndicator=Export\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Poland, Export","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Poland, Export","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAIADpEC3bdu2bQmhQEmSJEmStJxAt23btm1\u002fnUCSJEmSJJ2dQAAAAAAAgJ1AkiRJkiQ9nkBJkiRJkkCfQNu2bdu2zaFAJUmSJEk4oUDpoosuuiKgQNFFF110BZ5A6aKLLrokoEBddNFFF3+gQNFFF1105aNAAAAAAICGqUBVVVVV1XqrQFVVVVVV\u002fqxAF1100UW0sEBVVVVV1WqvQEtLS0tL+a1Al5aWlpYysUCIh4eHh7+zQLW0tLS0sLlAtbS0tLRswkB4eHh4+PnFQNPS0tLSdstADw8PD0980UBLS0tLS7vVQEtLS0uL8NFAS0tLSwuO1EC1tLS0tKHXQLW0tLQ0zdZAAAAAAMAy2UCmpaWl5R\u002fbQOLh4eEhjNhAAAAAAIDx2EA8PDw8fGvcQNPS0tISvN9ADw8PD28P4EDi4eHhgWPgQA8PDw+PI+RAeHh4eLhQ5UB4eHh42OrmQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Poland\u003cbr\u003eIndicator=Import\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Poland, Import","line":{"color":"#1F77B4","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Poland, Import","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Global Average\u003cbr\u003eIndicator=Export\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Global Average, Export","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Global Average, Export","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"BGKlHiyNqkCejfrOxuOmQJVOK1TbxqVA6APli5YUpkD\u002f5eQ9FRKoQLOCwxdS7KdAzi1PUSs6qkDN1+rZIfquQJ5QCxiTz7FAlVEZlXEks0DLPofUBPa0QE9126\u002fhdbVADN3sXQEQtkCsDY61gYS1QE2jw08EebdAapWQrf+yuUCe2ImdCN+5QAHF8Z93GLpAsbwY+XtEuUBcxRl090m4QJSkRXoqIcVA1lemwSm4xEDru\u002fJmCzHFQDtyftQ9dshANksqsUs+zUDkZ4dLvffPQHMz98wk9NFA4jNyS\u002f6\u002f1EDXHjYK1PLWQLGsFiAjjNFAnT25P+KN1EAs2kJOJ\u002f\u002fXQH4E9xHcrNdAGfDJ4U4y2EAFH9GOuZXYQA+IIOPzr9VAysHu71M21UBCYfIFSvnWQBv0fCwsdNlAj5I1BPmM2EA9r2lxySHXQE6O5\u002fbv2NtAEHws4S6T3kD7sy8XYjreQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Global Average\u003cbr\u003eIndicator=Import\u003cbr\u003eYear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Global Average, Import","line":{"color":"#FF7F0E","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Global Average, Import","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"MlUwKqnYo0AqQZ4ShNejQO5UHh34UaNASr6Am3k7o0AF8DOXFM+kQOBN1tfAKaVAUADjiEXXp0Bv9EZv9ESsQOKPW5f3KrBAVVkvPjG\u002fsUDGa8USKpaxQDlqXDnqzrJAoVKFASWFs0D90J502rGyQCMjIyMDdbRAr9DcTuVXtUAdcJtQo\u002fy1QKWBo\u002fXkLbZAxsfhu ...

# %% [markdown]
# ## Treemap

# %%
exports = merchandise[(merchandise['Indicator'] == "Import") & (merchandise['Year'] == 2023)]

exports_grouped = exports.groupby(['Reporter', 'Product'], as_index=False)['Value'].sum()

fig = px.treemap(exports_grouped,
                    path=['Reporter', 'Product'],
                    values='Value',
                    title='Export Value by Country and Product (2023)',
                    template='simple_white')
fig.update_traces(textinfo='label+value')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="42805b64-6462-4688-808f-09545d1ddfb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("42805b64-6462-4688-808f-09545d1ddfb1")) {                    Plotly.newPlot(                        "42805b64-6462-4688-808f-09545d1ddfb1",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eValue=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Afghanistan\u002fAgricultural products","Afghanistan\u002fAutomotive products","Afghanistan\u002fChemicals","Afghanistan\u002fClothing","Afghanistan\u002fElectronic data processing and office equipment","Afghanistan\u002fFood","Afghanistan\u002fFuels","Afghanistan\u002fFuels and mining products","Afghanistan\u002fIntegrated circuits and electronic components","Afghanistan\u002fIron and steel","Afghanistan\u002fMachinery and transport equipment","Afghanistan\u002fManufactures","Afghanistan\u002fOffice and telecom equipment","Afghanistan\u002fPharmaceuticals","Afghanistan\u002fTelecommunications equipment","Afghanistan\u002fTextiles","Afghanistan\u002fTransport equipment","Albania\u002fAgricultural products","Albania\u002fAutomotive products","Albania\u002fChemicals","Albania\u002fClothing","Albania\u002fElectronic data processing and office equipment","Albania\u002fFood","Albania\u002fFuels","Albania\u002fFuels and mining products","Albania\u002fIntegrated circuits and electronic components","Albania\u002fIron and steel","Albania\u002fMachinery and transport equipment","Albania\u002fManufactures","Albania\u002fOffice and telecom equipment","Albania\u002fPharmaceuticals","Albania\u002fTelecommunications equipment","Albania\u002fTextiles","Albania\u002fTransport equipment","Algeria\u002fAgricultural products","Algeria\u002fAutomotive products","Algeria\u002fChemicals","Algeria\u002fClothing","Algeria\u002fElectronic data processing and office equipment","Algeria\u002fFood","Algeria\u002fFuels","Algeria\u002fFuels and mining products","Algeria\u002fIntegrated circuits and electronic components","Algeria\u002fIron and steel","Algeria\u002fMachinery and transport equipment","Algeria\u002fManufactures","Algeria\u002fOffice and telecom equipment","Algeria\u002fPharmaceuticals","Algeria\u002fTelecommunications equipment","Algeria\u002fTextiles","Algeria\u002fTransport equipment","Angola\u002fAgricultural products","Angola\u002fAutomotive products","Angola\u002fChemicals","Angola\u002fClothing","Angola\u002fElectronic data processing and office equipment","Angola\u002fFood","Angola\u002fFuels","Angola\u002fFuels and mining products","Angola\u002fIntegrated circuits and electronic components","Angola\u002fIron and steel","Angola\u002fMachinery and transport equipment","Angola\u002fManufactures","Angola\u002fOffice and telecom equipment","Angola\u002fPharmaceuticals","Angola\u002fTelecommunications equipment","Angola\u002fTextiles","Angola\u002fTransport equipment","Antigua and Barbuda\u002fAgricultural products","Antigua and Barbuda\u002fAutomotive products","Antigua and Barbuda\u002fChemicals","Antigua and Barbuda\u002fClothing","Antigua and Barbuda\u002fElectronic data processing and office equipment","Antigua and Barbuda\u002fFood","Antigua and Barbuda\u002fFuels","Antigua and Barbuda\u002fFuels and mining products","Antigua and Barbuda\u002fIntegrated circuits and electronic components","Antigua and Barbuda\u002fIron and steel","Antigua and Barbuda\u002fMachinery and transport equipment","Antigua and Barbuda\u002fManufactures","Antigua and Barbuda\u002fOffice and telecom equipment","Antigua and Barbuda\u002fPharmaceuticals","Antigua and Barbuda\u002fTelecommunications equipment","Anti ...

# %% [markdown]
# ## Leaderboard

# %%
exports = services[services["Indicator"] == "Export"]

grouped = exports.groupby(["Year", "Reporter"])["Value"].sum().reset_index()

grouped["Rank"] = grouped.groupby("Year")["Value"].rank(ascending=False, method="min")

top_exporters = grouped.groupby("Reporter")["Value"].sum().nlargest(10).index

top_data = grouped[grouped["Reporter"].isin(top_exporters)]

fig = px.line(
    top_data,
    x="Year",
    y="Rank",
    color="Reporter",
    markers=True,
    title="Leaderboard of Top 10 Exporters Over Time (Services)"
)

fig.update_layout(
    xaxis_title="Year",
    legend_title="Country",
    template="plotly_white",
    legend=dict(
        orientation="h",
        yanchor="top",
        y=-0.2,
        xanchor="center",
        x=0.5
    )
)

fig.update_yaxes(
    autorange="reversed",      
    title="Export Rank",
    tickmode="linear",         
    dtick=1                   
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="28165e71-d4a6-48ac-8057-456742818f60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("28165e71-d4a6-48ac-8057-456742818f60")) {                    Plotly.newPlot(                        "28165e71-d4a6-48ac-8057-456742818f60",                        [{"hovertemplate":"Reporter=Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Asia","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Asia-Pacific Economic Cooperation (APEC)\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia-Pacific Economic Cooperation (APEC)","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Asia-Pacific Economic Cooperation (APEC)","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=G-20\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"G-20","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"G-20","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=North America\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"North America","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=United States of America\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States of America","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"United States of America","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=WTO Members\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"WTO Members","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"WTO Members","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAA ...

# %%
exports = merchandise[merchandise["Indicator"] == "Export"]

grouped = exports.groupby(["Year", "Reporter"])["Value"].sum().reset_index()

grouped["Rank"] = grouped.groupby("Year")["Value"].rank(ascending=False, method="min")

top_exporters = grouped.groupby("Reporter")["Value"].sum().nlargest(10).index

top_data = grouped[grouped["Reporter"].isin(top_exporters)]

fig = px.line(
    top_data,
    x="Year",
    y="Rank",
    color="Reporter",
    markers=True,
    title="Leaderboard of Top 10 Exporters Over Time (Merchandise)"
)

fig.update_layout(
    xaxis_title="Year",
    legend_title="Country",
    template="plotly_white",
    legend=dict(
        orientation="h",
        yanchor="top",
        y=-0.2,
        xanchor="center",
        x=0.5
    )
)

fig.update_yaxes(
    autorange="reversed",      
    title="Export Rank",
    tickmode="linear",         
    dtick=1                   
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="56ea0cbf-5745-4dfb-81e7-9afddc1ca7eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("56ea0cbf-5745-4dfb-81e7-9afddc1ca7eb")) {                    Plotly.newPlot(                        "56ea0cbf-5745-4dfb-81e7-9afddc1ca7eb",                        [{"hovertemplate":"Reporter=China\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"China","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=France\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Germany\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Hong Kong, China\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hong Kong, China","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Hong Kong, China","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Italy\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Japan\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Japan","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"vAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkB+UH5gfnBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Reporter=Korea, Republic of\u003cbr\u003eYear=%{x}\u003cbr\u003eRank=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Korea, Republic of","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Korea, Republic of","orientation":"v","showlegend":true,"x":{"dtype":"i2","bd ...

# %% [markdown]
# ## Bubble Map

# %%
df_bubble = merchandise[merchandise["Indicator"] == "Export"].groupby(['Reporter', 'ReporterISO3A'], as_index=False)['Value'].sum()

min_bubble_size = 1
max_bubble_size = 50

size_scaled = df_bubble['Value'] / df_bubble['Value'].max() * (max_bubble_size - min_bubble_size) + min_bubble_size

fig_bubble = px.scatter_geo(
    df_bubble,
    locations="ReporterISO3A",
    color="Value",
    size=size_scaled,
    hover_name="Reporter",
    projection="natural earth",
    title="Sum of exports over the whole timeframe",
    template="plotly_white"
)

fig_bubble.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="026c41ec-12b6-494b-a153-e56ab03b1276" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("026c41ec-12b6-494b-a153-e56ab03b1276")) {                    Plotly.newPlot(                        "026c41ec-12b6-494b-a153-e56ab03b1276",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003esize=%{marker.size}\u003cbr\u003eReporterISO3A=%{location}\u003cbr\u003eValue=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Albania","Algeria","Angola","Antigua and Barbuda","Argentina","Armenia","Aruba, Netherlands with respect to","Australia","Austria","Azerbaijan","Bahamas","Bahrain, Kingdom of","Bangladesh","Barbados","Belarus","Belgium","Belgium-Luxembourg","Belize","Benin","Bermuda","Bhutan","Bolivia, Plurinational State of","Bosnia and Herzegovina","Botswana","Brazil","Brunei Darussalam","Bulgaria","Burkina Faso","Burundi","Cabo Verde","Cambodia","Cameroon","Canada","Cayman Islands","Central African Republic","Chile","China","Chinese Taipei","Colombia","Comoros","Congo","Cook Islands","Costa Rica","Croatia","Cuba","Cyprus","Czech Republic","C\u00f4te d'Ivoire","Democratic Republic of the Congo","Denmark","Djibouti","Dominica","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Estonia","Eswatini","Ethiopia","European Union","Fiji","Finland","France","French Polynesia","Gabon","Georgia","German Democratic Republic","Germany","Ghana","Greece","Greenland","Grenada","Guam","Guatemala","Guinea","Guinea-Bissau","Guyana","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kazakhstan","Kenya","Kiribati","Korea, Republic of","Kuwait, the State of","Kyrgyz Republic","Lao People's Democratic Republic","Latvia","Lebanese Republic","Lesotho","Liberia","Libya","Lithuania","Luxembourg","Macao, China","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Mauritania","Mauritius","Mexico","Micronesia, Federated States of","Moldova, Republic of","Mongolia","Montenegro","Montserrat","Morocco","Mozambique","Myanmar","Namibia","Nauru","Nepal","Netherlands","Netherlands Antilles","New Caledonia","New Zealand","Nicaragua","Niger","Nigeria","North Macedonia","Norway","Oman","Pakistan","Palau","Panama","Papua New Guinea","Paraguay","Peru","Philippines","Poland","Portugal","Qatar","Romania","Russian Federation","Rwanda","Saint Kitts and Nevis","Saint Lucia","Saint Pierre and Miquelon","Saint Vincent and the Grenadines","Samoa","Sao Tom\u00e9 and Principe","Saudi Arabia, Kingdom of","Senegal","Serbia","Serbia and Montenegro","Seychelles","Sierra Leone","Singapore","Slovak Republic","Slovenia","Solomon Islands","Somalia","South Africa","Spain","Sri Lanka","Sudan","Suriname","Sweden","Switzerland","Syrian Arab Republic","Tajikistan","Tanzania","Thailand","The Gambia","Timor-Leste","Togo","Tonga","Trinidad and Tobago","Tunisia","Turkmenistan","T\u00fcrkiye","U.S.S.R.","Uganda","Ukraine","United Arab Emirates","United Kingdom","United States of America","Uruguay","Uzbekistan","Vanuatu","Venezuela, Bolivarian Republic of","Viet Nam","Yemen","Yugoslavia, Socialist Federal Republic of","Zambia","Zimbabwe"],"legendgroup":"","locations":["AFG","ALB","DZA","AGO","ATG","ARG","ARM","ABW","AUS","AUT","AZE","BHS","BHR","BGD","BRB","BLR","BEL","BLX","BLZ","BEN","BMU","BTN","BOL","BIH","BWA","BRA","BRN","BGR","BFA","BDI","CPV","KHM","CMR","CAN","CYM","CAF","CHL","CHN","CHT","COL","COM","COG","COK","CRI","HRV","CUB","CYP","CZE","CIV","COD","DNK","DJI","DMA","DOM","ECU","EGY","SLV","GNQ","ERI","EST","SWZ","ETH","EEC","FJI","FIN","FRA","PYF","GAB","GEO","DDR","DEU","GH ...

# %% [markdown]
# ## Sunburst

# %%
es = px.sunburst(
  merchandise, path=["Indicator", "Product"], values="Value",
  color="Indicator",
  title="The amount of Productes Imported and Exported"
)
es.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="fa3745c6-9eae-4523-9cae-285ef4f3eb63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fa3745c6-9eae-4523-9cae-285ef4f3eb63")) {                    Plotly.newPlot(                        "fa3745c6-9eae-4523-9cae-285ef4f3eb63",                        [{"branchvalues":"total","customdata":[["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Export"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"],["Import"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eValue=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eIndicator=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Export\u002fAgricultural products","Export\u002fChemicals","Export\u002fPharmaceuticals","Export\u002fClothing","Export\u002fIron and steel","Export\u002fMachinery and transport equipment","Export\u002fAutomotive products","Export\u002fManufactures","Export\u002fOffice and telecom equipment","Export\u002fIntegrated circuits and electronic components","Export\u002fTelecommunications equipment","Export\u002fTransport equipment","Export\u002fTextiles","Export\u002fFuels and mining products","Export\u002fFuels","Export\u002fElectronic data processing and office equipment","Export\u002fFood","Export","Import\u002fFuels","Import\u002fFood","Import\u002fManufactures","Import\u002fChemicals","Import\u002fPharmaceuticals","Import\u002fClothing","Import\u002fIron and steel","Import\u002fMachinery and transport equipment","Import\u002fAutomotive products","Import\u002fOffice and telecom equipment","Import\u002fElectronic data processing and office equipment","Import\u002fIntegrated circuits and electronic components","Import\u002fTelecommunications equipment","Import\u002fTransport equipment","Import\u002fTextiles","Import\u002fFuels and mining products","Import","Import\u002fAgricultural products"],"labels":["Agricultural products","Chemicals","Pharmaceuticals","Clothing","Iron and steel","Machinery and transport equipment","Automotive products","Manufactures","Office and telecom equipment","Integrated circuits and electronic components","Telecommunications equipment","Transport equipment","Textiles","Fuels and mining products","Fuels","Electronic data processing and office equipment","Food","Export","Fuels","Food","Manufactures","Chemicals","Pharmaceuticals","Clothing","Iron and steel","Machinery and transport equipment","Automotive products","Office and telecom equipment","Electronic data processing and office equipment","Integrated circuits and electronic components","Telecommunications equipment","Transport equipment","Textiles","Fuels and mining products","Import","Agricultural products"],"marker":{"colors":["#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B"]},"name":"","parents":["Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","Export","","Import","Import","Import","Import","Import","Import","Import","Import","Import","Import","Import","Import","Import","Import","Import","Import","","Import"],"values":{"dtype":"f8","bdata":"AAAAGOHLj0EAAAA0Vx ...

# %%
# command we used for generating html:
# jupyter nbconvert --to html --template jp-extended main.ipynb
